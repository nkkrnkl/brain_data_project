# %%
# Hello Niki, run the below code to get the development dataset on your local machine. It's too large to upload to github.

from nilearn import datasets
from nilearn.datasets import _utils

_utils._REQUESTS_TIMEOUT = 300  # seconds
development_dataset = datasets.fetch_development_fmri(n_subjects=None, reduce_confounds=True, data_dir=None, resume=True, verbose=1, age_group='both')
# Out:
# [fetch_development_fmri] Added README.md to /Users/elliotwaxman/nilearn_data
# [fetch_development_fmri] Dataset created in /Users/elliotwaxman/nilearn_data/development_fmri
# [fetch_development_fmri] Added README.md to /Users/elliotwaxman/nilearn_data/development_fmri
# [fetch_development_fmri] Dataset created in /Users/elliotwaxman/nilearn_data/development_fmri/development_fmri
# [fetch_development_fmri] Downloading data from https://osf.io/yr3av/download ...
# [fetch_development_fmri]  ...done. (2 seconds, 0 min)
#
# [fetch_development_fmri] Dataset found in /Users/elliotwaxman/nilearn_data/development_fmri/development_fmri
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff4282286e80017c41c0a/ ...
# [fetch_development_fmri]  ...done. (1 seconds, 0 min)
#
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff4292286e80017c41c0f/ ...
# [fetch_development_fmri]  ...done. (2 seconds, 0 min)
#
# ...

# %%
print(development_dataset.keys())
# Out:
# dict_keys(['func', 'confounds', 'phenotypic', 'description', 't_r'])

# %%
print(len(development_dataset.func), len(development_dataset.confounds))
# Out:
# 155 155

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/projects/brain_data_project/.venv/lib/python3.13/site-packages/sklearn/utils/_bunch.py:57, in Bunch.__getattr__(self, key)
#      56 try:
# ---> 57     return self[key]
#      58 except KeyError:
#
# File ~/projects/brain_data_project/.venv/lib/python3.13/site-packages/sklearn/utils/_bunch.py:42, in Bunch.__getitem__(self, key)
#      38     warnings.warn(
#      39         self._deprecated_key_to_warnings[key],
#      40         FutureWarning,
#      41     )
# ---> 42 return super().__getitem__(key)
#
# KeyError: 'shape'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(development_dataset.shape())
#
# ...
